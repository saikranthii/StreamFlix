# %%
import pandas as pd
import ast
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import requests
import os

# Load datasets
movies_df = pd.read_csv('../data/movies.csv')
credits_df = pd.read_csv('../data/credits.csv')

# Parse genres (JSON string to list of names)
movies_df['genres'] = movies_df['genres'].apply(lambda x: ' '.join([d['name'] for d in ast.literal_eval(x)]) if pd.notna(x) else '')

# Parse cast and crew (JSON string to space-separated names)
credits_df['cast'] = credits_df['cast'].apply(lambda x: ' '.join([d['name'] for d in ast.literal_eval(x)[:3]]) if pd.notna(x) else '')
credits_df['crew'] = credits_df['crew'].apply(lambda x: ' '.join([d['name'] for d in ast.literal_eval(x) if d['job'] == 'Director']) if pd.notna(x) else '')

# Merge datasets on title
merged_df = pd.merge(movies_df, credits_df, on='title', how='left')

# Filter for Indian movies (based on language or country)
indian_languages = ['hi', 'te', 'ta', 'ml', 'kn', 'mr', 'pa', 'bn']
merged_df = merged_df[
    merged_df['original_language'].isin(indian_languages) |
    merged_df['production_countries'].str.contains('India', na=False)
]

# Function to get poster URL with error handling
def get_poster(title, year, api_key):
    if not api_key or api_key == "YOUR_ACTUAL_TMDB_API_KEY":
        return f"https://via.placeholder.com/200x300?text={title.replace(' ', '+')}"
    try:
        # Test API key validity with a simple request
        test_response = requests.get(f"https://api.themoviedb.org/3/configuration?api_key={api_key}", timeout=5)
        test_response.raise_for_status()
        response = requests.get(
            f"https://api.themoviedb.org/3/search/movie?api_key={api_key}&query={title}&year={year}",
            timeout=5
        )
        response.raise_for_status()
        data = response.json()
        if data.get('results') and len(data['results']) > 0 and data['results'][0].get('poster_path'):
            return f"https://image.tmdb.org/t/p/w200{data['results'][0]['poster_path']}"
        print(f"No poster found for {title}")
        return f"https://via.placeholder.com/200x300?text={title.replace(' ', '+')}"
    except requests.exceptions.RequestException as e:
        print(f"API request failed for {title}: {e}")
        return f"https://via.placeholder.com/200x300?text={title.replace(' ', '+')}"

# Add poster URLs
tmdb_api_key = "YOUR_ACTUAL_TMDB_API_KEY"  # Replace with your TMDB API key
merged_df['poster'] = merged_df.apply(lambda row: get_poster(row['title'], row['release_date'][:4], tmdb_api_key), axis=1)

# Save merged dataset
merged_df.to_csv('../data/merged_indian_movies.csv', index=False)
print(f"Merged dataset saved with {len(merged_df)} Indian movies.")
# Out:
# Merged dataset saved with 56 Indian movies.

# %%
import pandas as pd

# Load the movies dataset
movies_df = pd.read_csv('../data/movies.csv')

# Generate image links based on movie titles
movies_df['image_link'] = movies_df['title'].apply(lambda x: f"https://via.placeholder.com/200x450?text={x.replace(' ', '+')}")

# Select only title and image_link columns
image_links_df = movies_df[['title', 'image_link']]

# Save to a new CSV file
image_links_df.to_csv('../data/image_links.csv', index=False)
print(f"Generated image_links.csv with {len(image_links_df)} entries.")
# Out:
# Generated image_links.csv with 4803 entries.

# %%
dfff=pd.read_csv('./TeluguMovies_dataset.csv')
print(dfff.columns)
# Out:
# Index(['Unnamed: 0', 'Movie', 'Year', 'Certificate', 'Genre', 'Overview',
#        'Runtime', 'Rating', 'No.of.Ratings'],
#       dtype='object')

# %%
import pandas as pd
import requests
import time

# Load the Telugu dataset
telugu_df = pd.read_csv("./TeluguMovies_dataset.csv")

# Drop unnecessary column if it's just an index
telugu_df = telugu_df.drop(columns=['Unnamed: 0']) if 'Unnamed: 0' in telugu_df.columns else telugu_df

# Initial manual mappings (for known titles to speed up process)
title_to_tmdb_id = {
    "Bahubali: The Beginning": 271726,
    "Baahubali 2: The Conclusion": 325561,
    "RRR": 615656,
    "Pushpa: The Rise": 610149,
    "Magadheera": 345013,
    "Arjun Reddy": 521077,
    "Ala Vaikunthapurramuloo": 658915,
    "Sye Raa Narasimha Reddy": 543099,
    "Jersey": 562974,
    "1 - Nenokkadine": 134374,
    "Dhoom: 3": 100302,
    "Ra.One": 56703,
    "Dhoom: 2": 1887,
    "Eega": 108063,
    "Krrish 3": 184315,
    "Bharat Ane Nenu": 488015,
    "Theri": 399177,
    "Dookudu": 101863,
    "Athadu": 125962
}

# Map titles to TMDB IDs dynamically
api_key = "8265bd1679663a7ea12ac168da84d2e8"
unmapped_titles = []

for index, row in telugu_df.iterrows():
    title = row['Movie']
    if title in title_to_tmdb_id:
        telugu_df.at[index, 'id'] = title_to_tmdb_id[title]
    else:
        search_url = f"https://api.themoviedb.org/3/search/movie?api_key={api_key}&query={title}&language=en-US"
        try:
            response = requests.get(search_url, timeout=10)
            response.raise_for_status()
            data = response.json()
            if data['results']:
                tmdb_id = data['results'][0]['id']
                telugu_df.at[index, 'id'] = tmdb_id
                title_to_tmdb_id[title] = tmdb_id  # Update dictionary for future use
                print(f"Mapped {title} to TMDB ID {tmdb_id}")
            else:
                telugu_df.at[index, 'id'] = 100000 + index  # Fallback ID
                unmapped_titles.append(title)
                print(f"No TMDB match found for {title}, using fallback ID {100000 + index}")
        except requests.exceptions.RequestException as e:
            telugu_df.at[index, 'id'] = 100000 + index  # Fallback on error
            unmapped_titles.append(title)
            print(f"Error searching TMDB for {title}: {e}, using fallback ID {100000 + index}")
        time.sleep(0.5)  # Avoid hitting TMDB rate limits (max 40 requests per 10 seconds)

# Map columns
telugu_df = telugu_df.rename(columns={
    'Movie': 'title',
    'Genre': 'genres',
    'Overview': 'overview'
})
telugu_df['original_language'] = 'te'
telugu_df['poster'] = None

# Fetch posters using TMDB IDs
for index, row in telugu_df.iterrows():
    movie_id = row['id']
    url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}&language=en-US"
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        poster_path = data.get('poster_path')
        if poster_path:
            telugu_df.at[index, 'poster'] = f"https://image.tmdb.org/t/p/w500/{poster_path}"
        else:
            print(f"No poster path found for ID {movie_id} ({row['title']})")
    except (KeyError, requests.exceptions.RequestException) as e:
        print(f"Error fetching poster for ID {movie_id} ({row['title']}): {e}")

# Save the enhanced dataset
telugu_df.to_csv("./TeluguMovies_enhanced.csv", index=False)
print(telugu_df.head())
print(f"Unmapped titles: {unmapped_titles}")
# Out:
# Mapped Dhoom:3 to TMDB ID 44977
# Mapped Dhoom:2 to TMDB ID 14194
# Mapped Rangasthalam to TMDB ID 461126
# Mapped War to TMDB ID 10431
# Mapped Saaho to TMDB ID 454292
# Mapped Pokiri to TMDB ID 23381
# Mapped Sarkar to TMDB ID 624102
# Mapped The Ghazi Attack to TMDB ID 442405
# Mapped Kabali to TMDB ID 366080
# Mapped MSG: The Messenger of God to TMDB ID 318848
# Mapped Nanban to TMDB ID 69537
# Mapped Srimanthudu to TMDB ID 319817
# No TMDB match found for Veer - Vivegam, using fallback ID 100024
# Mapped Billa 2 to TMDB ID 116185
# Mapped Manam to TMDB ID 253533
# Mapped 7 Aum Arivu to TMDB ID 86718
# Mapped Bigil to TMDB ID 563309
# Mapped Business Man to TMDB ID 366683
# Mapped Geetha Govindam to TMDB ID 540468
# Mapped Mahanati to TMDB ID 459713
# Mapped Spyder to TMDB ID 337608
# Mapped Nannaku Prematho to TMDB ID 365187
# Mapped Dabangg 3 to TMDB ID 496339
# Mapped MSG 2 the Messenger to TMDB ID 373195
# Mapped Manikarnika: The Queen of Jhansi to TMDB ID 491622
# Mapped Race Gurram to TMDB ID 262227
# Mapped Okkadu to TMDB ID 94965
# Mapped Bommarillu to TMDB ID 31626
# Mapped Atharintiki Daaredi to TMDB ID 224061
# Mapped Khaleja to TMDB ID 56986
# Mapped Yennai Arindhaal to TMDB ID 300983
# Mapped Thalaivaa to TMDB ID 202616
# Mapped Kaala to TMDB ID 780524
# Mapped Bairavaa to TMDB ID 411717
# Mapped Goodachari to TMDB ID 540189
# Mapped Puli to TMDB ID 353501
# Mapped Pulimurugan to TMDB ID 353501
# Mapped Veeram to TMDB ID 1142313
# Mapped Vedam to TMDB ID 97342
# Mapped Yevadu to TMDB ID 215248
# Mapped Aravindha Sametha Veera Raghava to TMDB ID 534530
# Mapped Billa to TMDB ID 116185
# Mapped Janatha Garage to TMDB ID 405924
# Mapped Gabbar Singh to TMDB ID 111836
# Mapped Temper to TMDB ID 1340597
# Mapped Game Over to TMDB ID 12279
# Mapped Singam 2 to TMDB ID 191735
# Mapped Dhruva to TMDB ID 1109487
# Mapped Jalsa to TMDB ID 73578
# Mapped Maharshi to TMDB ID 541487
# Mapped Pelli Choopulu to TMDB ID 393841
# Mapped Arya 2 to TMDB ID 34763
# Mapped Chekka Chivantha Vaanam to TMDB ID 504184
# Mapped Naa Peru Surya Na Illu India to TMDB ID 500494
# Mapped Ki & Ka to TMDB ID 413646
# Mapped Seethamma Vakitlo Sirimalle Chettu to TMDB ID 193197
# Mapped Singam 3 to TMDB ID 376440
# Mapped Agent Sai Srinivasa Athreya to TMDB ID 610482
# Mapped Jai Lava Kusa to TMDB ID 101736
# Mapped Arya to TMDB ID 20344
# Mapped Maattrraan to TMDB ID 139662
# Mapped Kochadaiiyaan to TMDB ID 256968
# Mapped Thaanaa Serndha Koottam to TMDB ID 433121
# Mapped OK Kanmani to TMDB ID 329135
# Mapped Dear Comrade to TMDB ID 563604
# Mapped Happy Days to TMDB ID 19100
# Mapped Sarileru Neekevvaru to TMDB ID 607313
# Mapped Julayi to TMDB ID 125835
# Mapped Kshanam to TMDB ID 1296401
# Mapped Oopiri to TMDB ID 369925
# Mapped Baadshah to TMDB ID 41902
# Mapped 3 to TMDB ID 829557
# Mapped Sarrainodu to TMDB ID 374954
# Mapped Kick to TMDB ID 280690
# Mapped Leader to TMDB ID 356600
# Mapped Anjaan to TMDB ID 876515
# Mapped Khushi to TMDB ID 81070
# Mapped Maya Bazaar to TMDB ID 1156124
# Mapped Rakhta Charitra to TMDB ID 55808
# Mapped Mirchi to TMDB ID 176590
# Mapped Chatrapathi to TMDB ID 79210
# Mapped C/o Kancharapalem to TMDB ID 544795
# Mapped Sachein to TMDB ID 63641
# Mapped Murari to TMDB ID 85813
# Mapped Vikramarkudu to TMDB ID 40909
# Mapped Kuruthipunal to TMDB ID 1202507
# Mapped Brindaavanam to TMDB ID 413042
# Mapped Panjaa to TMDB ID 80539
# No TMDB match found for Nuvvu Naaku Nachchav, using fallback ID 100103
# Mapped Gopala Gopala to TMDB ID 279449
# Mapped Kaappaan to TMDB ID 533885
# Mapped Aagadu to TMDB ID 294413
# Mapped Masss to TMDB ID 67158
# Mapped Maanagaram to TMDB ID 412096
# Mapped Drushyam to TMDB ID 279450
# Mapped Yamadonga to TMDB ID 77043
# Mapped S/O Satyamurthy to TMDB ID 333876
# Mapped Tholi Prema to TMDB ID 500527
# Mapped Awe! to TMDB ID 500723
# Mapped Yatra to TMDB ID 322481
# Mapped Fidaa to TMDB ID 467649
# Mapped Oosaravelli to TMDB ID 80281
# Mapped Evaru to TMDB ID 607310
# Mapped Odiyan to TMDB ID 461166
# Mapped Khaidi No 150 to TMDB ID 412326
# Mapped NGK to TMDB ID 532869
# Mapped Duvvada Jagannadham to TMDB ID 443635
# Mapped Bale Bale Magadivoy to TMDB ID 367553
# Mapped Shiva to TMDB ID 1316580
# Mapped Manmadhudu to TMDB ID 81083
# Mapped Mr Perfect to TMDB ID 52444
# Mapped Orange to TMDB ID 1039021
# Mapped Anirudh to TMDB ID 1318980
# Mapped Gamyam to TMDB ID 931171
# Mapped Kanche to TMDB ID 364795
# Mapped Naayak to TMDB ID 182954
# Mapped Malliswari to TMDB ID 94957
# Mapped Nuvvostanante Nenoddantana to TMDB ID 74154
# Mapped Ye Maaya Chesave to TMDB ID 63430
# Mapped Sagara Sangamam to TMDB ID 30153
# Mapped Rudhramadevi to TMDB ID 315009
# Mapped Cameraman Gangatho Rambabu to TMDB ID 138667
# Mapped Majili to TMDB ID 571610
# Mapped Uttama Villain to TMDB ID 273870
# Mapped Arundhati to TMDB ID 1087471
# Mapped Agnyaathavaasi to TMDB ID 495362
# Mapped Pilla Zamindar to TMDB ID 85818
# Mapped 100% Love to TMDB ID 314606
# Mapped Aa Naluguru to TMDB ID 23971
# Mapped Darling to TMDB ID 24134
# Mapped Aha Naa Pellanta to TMDB ID 37612
# Mapped Vinaya Vidheya Rama to TMDB ID 566402
# Mapped Happy to TMDB ID 86577
# Mapped Ala Modalaindi to TMDB ID 57010
# Mapped Prasthanam to TMDB ID 52522
# Mapped Dhee to TMDB ID 1198208
# Mapped Iddarammayilatho to TMDB ID 197999
# Mapped Simhadri to TMDB ID 1107402
# Mapped Taxiwaala to TMDB ID 520393
# Mapped Parugu to TMDB ID 23776
# Mapped Rakhta Charitra 2 to TMDB ID 55808
# Mapped Maryada Ramanna to TMDB ID 54757
# Mapped Rachcha to TMDB ID 120956
# Mapped HIT to TMDB ID 103314
# Mapped Nota to TMDB ID 357452
# Mapped U Turn to TMDB ID 10155
# Mapped Thammudu to TMDB ID 199808
# Mapped Zanjeer to TMDB ID 218898
# Mapped Ezra to TMDB ID 22366
# Mapped Bhaagamathie to TMDB ID 485789
# Mapped Adhurs to TMDB ID 785354
# Mapped Aditya 369 to TMDB ID 280363
# Mapped Sardaar Gabbar Singh to TMDB ID 371811
# Mapped Gitanjali to TMDB ID 148808
# Mapped Ninnu Kori to TMDB ID 465099
# Mapped Indra to TMDB ID 25882
# Mapped Vishwaroopam 2 to TMDB ID 278358
# Mapped Oru Adaar Love to TMDB ID 505432
# Mapped Brochevarevarura to TMDB ID 611754
# Mapped 7/G Rainbow Colony to TMDB ID 24448
# Mapped Tagore to TMDB ID 97343
# Mapped Gang Leader to TMDB ID 612402
# Mapped Bujjigaadu: Made in Chennai to TMDB ID 117029
# Mapped Sye to TMDB ID 1209353
# Mapped Yevade Subramanyam to TMDB ID 332831
# Mapped Mathu Vadalara to TMDB ID 657853
# Mapped Katamarayudu to TMDB ID 440794
# Mapped Maari 2 to TMDB ID 493178
# Mapped Gautamiputra Satakarni to TMDB ID 434395
# Mapped Rx 100 to TMDB ID 535369
# Mapped A... Aa to TMDB ID 105103
# Mapped Aalavandhan to TMDB ID 66346
# Mapped F2: Fun and Frustration to TMDB ID 566914
# Mapped The House Next Door to TMDB ID 231171
# Mapped Krishna Gaadi Veera Prema Gaadha to TMDB ID 384420
# Mapped Prince to TMDB ID 307609
# Mapped Sankarabharanam to TMDB ID 405800
# Mapped Thoongaavanam to TMDB ID 363178
# Mapped Govindudu Andari Vaadele to TMDB ID 295590
# Mapped Anand to TMDB ID 1206195
# No TMDB match found for Raja Kumarudu, using fallback ID 100196
# Mapped Baba to TMDB ID 1179157
# Mapped Dhammu to TMDB ID 113728
# No TMDB match found for Ramayya Vastavayya, using fallback ID 100199
# Mapped NTR: Kathanayakudu to TMDB ID 568522
# Mapped Chirutha to TMDB ID 84504
# Mapped Thaandavam to TMDB ID 78686
# Mapped Athidhi to TMDB ID 56996
# Mapped Kshana Kshanam to TMDB ID 81072
# Mapped Penguin to TMDB ID 1143088
# No TMDB match found for Rudra Veena, using fallback ID 100206
# Mapped Legend to TMDB ID 276907
# Mapped Annamayya to TMDB ID 80798
# Mapped Badrinath to TMDB ID 413646
# Mapped Nenu Local to TMDB ID 439057
# Mapped Oh Baby... to TMDB ID 607091
# Mapped Sketch to TMDB ID 624540
# Mapped Hello Guru Prema Kosame to TMDB ID 517508
# Mapped Rabhasa to TMDB ID 307614
# Mapped Sainikudu to TMDB ID 85824
# Mapped Ishq to TMDB ID 29988
# Mapped Arjun to TMDB ID 96112
# Mapped Badri to TMDB ID 413646
# Mapped Krishnarjuna to TMDB ID 117844
# Mapped Hello to TMDB ID 1098152
# Mapped Saleem to TMDB ID 1139484
# Mapped Nijam to TMDB ID 66416
# Mapped Bruce Lee: The Fighter to TMDB ID 364080
# Mapped MCA Middle Class Abbayi to TMDB ID 485869
# Mapped Ee Nagaraniki Emaindi to TMDB ID 532789
# Mapped Nenu Sailaja to TMDB ID 376998
# Mapped Gentleman to TMDB ID 482495
# Mapped Student No. 1 to TMDB ID 82572
# Mapped Kumari 21F to TMDB ID 369949
# Mapped Love Ke Liye Kuch Bhi Karega to TMDB ID 142631
# Mapped Run Baby Run to TMDB ID 130371
# Mapped Chitralahari to TMDB ID 590012
# Mapped Shankar Dada MBBS to TMDB ID 148884
# Mapped Teen Maar to TMDB ID 63377
# Mapped Kanthaswamy to TMDB ID 25120
# Mapped Komaram Puli to TMDB ID 199800
# Mapped Rebel to TMDB ID 123156
# Mapped iSmart Shankar to TMDB ID 609108
# Mapped Anukokunda Oka Roju to TMDB ID 80862
# Mapped Bheeshma to TMDB ID 674779
# Mapped Karthikeya to TMDB ID 894762
# Mapped Desamuduru to TMDB ID 117058
# Mapped Gunde Jaari Gallanthayyinde to TMDB ID 181929
# Mapped Pailwan to TMDB ID 607294
# Mapped World Famous Lover to TMDB ID 659674
# Mapped Theeya Velai Seiyyanum Kumaru to TMDB ID 190663
# Mapped Raja The Great to TMDB ID 456431
# Mapped Kadaram Kondan to TMDB ID 561295
# Mapped Sammohanam to TMDB ID 530198
# Mapped Simha to TMDB ID 54404
# Mapped Aithe to TMDB ID 1357662
# Mapped Takkari Donga to TMDB ID 82727
# Mapped Kadhalil Sodhappuvadhu Yeppadi to TMDB ID 101793
# Mapped Pammal K. Sambandam to TMDB ID 66344
# Mapped Kanchana 2 to TMDB ID 330425
# Mapped Saroja to TMDB ID 803757
# Mapped Vel to TMDB ID 63274
# Mapped Pandavulu Pandavulu Thummeda to TMDB ID 253047
# Mapped Doosukeltha to TMDB ID 241120
# Mapped Gundamma Katha to TMDB ID 86146
# Mapped Oohalu Gusagusalade to TMDB ID 280548
# Mapped Rowdy to TMDB ID 974659
# Mapped Devadas to TMDB ID 1115734
# No TMDB match found for Sokkali Mainor, using fallback ID 100265
# Mapped Dhenikaina Ready to TMDB ID 171384
# Mapped Political Rowdy to TMDB ID 596092
# Mapped Anukshanam to TMDB ID 292140
# Mapped Stalin to TMDB ID 56448
# Mapped Godavari to TMDB ID 1171693
# Mapped Suryam to TMDB ID 305822
# Mapped Balu to TMDB ID 1071582
# Mapped Savyasachi to TMDB ID 536420
# Mapped Nene Raju Nene Mantri to TMDB ID 460699
# Mapped Varsham to TMDB ID 82322
# Mapped Kaashmora to TMDB ID 371420
# Mapped Run Raja Run to TMDB ID 284837
# Mapped Abhiyum Naanum to TMDB ID 40617
# Mapped Eedo Rakam Aado Rakam to TMDB ID 392939
# Mapped Asthram to TMDB ID 115070
# Mapped Ready to TMDB ID 65946
# Mapped Irandam Ulagam to TMDB ID 69510
# Mapped Sree to TMDB ID 1243975
# Mapped Aadi to TMDB ID 1069884
# Mapped Jhummandi Naadam to TMDB ID 117421
# Mapped Pandurangadu to TMDB ID 280323
# Mapped Naani to TMDB ID 580811
# Mapped Game to TMDB ID 1408248
# Mapped Shatamanam Bhavati to TMDB ID 435410
# Mapped Mass to TMDB ID 423333
# Mapped Swamy Ra Ra to TMDB ID 181884
# Mapped Ekkadiki Pothavu Chinnavada to TMDB ID 426614
# Mapped Amazon Obhijaan to TMDB ID 496681
# Mapped Chi La Sow to TMDB ID 540215
# Mapped Kaathala Kaathala to TMDB ID 66349
# Mapped Kanchana 3 to TMDB ID 498580
# Mapped Vishnu to TMDB ID 78661
# Mapped Rakhi to TMDB ID 683034
# Mapped Oh My Friend to TMDB ID 86717
# Mapped Balupu to TMDB ID 204275
# Mapped Aadavari Matalaku Ardhalu Verule to TMDB ID 80826
# Mapped Prayanam to TMDB ID 437878
# Mapped Antariksham 9000 kmph to TMDB ID 566486
# Mapped Konchem Ishtam Konchem Kashtam to TMDB ID 85810
# Mapped Jamba Lakidi Pamba to TMDB ID 531897
# Mapped Kotigobba 2 to TMDB ID 389952
# Mapped Kaadhal to TMDB ID 752943
# Mapped Current Theega to TMDB ID 331939
# No TMDB match found for MalliRaava, using fallback ID 100309
# Mapped Saahasam Swaasaga Saagipo to TMDB ID 397486
# Mapped Premam to TMDB ID 341895
# Mapped Johnny to TMDB ID 920220
# Mapped King to TMDB ID 1241320
# Mapped Endrendrum Punnagai to TMDB ID 243706
# Mapped Mugamoodi to TMDB ID 69536
# Mapped NTR Mahanayakudu to TMDB ID 676542
# Mapped PSV Garuda Vega to TMDB ID 484423
# Mapped Kurukshetra to TMDB ID 81782
# Mapped Uu Kodathara Ulikki Padathara to TMDB ID 250649
# Mapped Mr. Nookayya to TMDB ID 307769
# Mapped Mirapakai to TMDB ID 57736
# Mapped Nenu Meeku Telusa...? to TMDB ID 82197
# Mapped Satya 2 to TMDB ID 242084
# Mapped Pooja to TMDB ID 1100532
# Mapped Naan Sigappu Manithan to TMDB ID 66274
# Mapped Sakthi to TMDB ID 373099
# Mapped Uyyala Jampala to TMDB ID 247501
# Mapped Khadgam to TMDB ID 81068
# Mapped Major Chandrakanth to TMDB ID 87681
# Mapped Bachchan to TMDB ID 255993
# Mapped Manu to TMDB ID 1172669
# Mapped Hyderabad Blues to TMDB ID 97438
# Mapped Bunny to TMDB ID 48610
# No TMDB match found for Ragile Gundelu, using fallback ID 100334
# Mapped Sri Rama Rajyam to TMDB ID 94987
# Mapped Varudu to TMDB ID 801505
# Mapped Rakshasudu to TMDB ID 606224
# Mapped Gharshana to TMDB ID 63671
# Mapped Gaganam to TMDB ID 59900
# Mapped Amar Akbar Anthony to TMDB ID 38022
# Mapped Kathakali to TMDB ID 368012
# Mapped Krishnarjuna Yudham to TMDB ID 500565
# Mapped Express Raja to TMDB ID 378774
# Mapped Kuselan to TMDB ID 12274
# Mapped Don to TMDB ID 92979
# Mapped Kantri to TMDB ID 81065
# Mapped Malli Malli Idhi Rani Roju to TMDB ID 326153
# Mapped Raju Bhai to TMDB ID 511680
# Mapped Ayogya to TMDB ID 543413
# Mapped Gudumba Shankar to TMDB ID 117093
# Mapped Potugadu to TMDB ID 240823
# Mapped Vastadu Naa Raju to TMDB ID 79820
# Mapped Dubai Seenu to TMDB ID 80926
# Mapped Dongata to TMDB ID 381677
# Mapped Sahasam to TMDB ID 1182487
# Mapped Dynamite to TMDB ID 511130
# Mapped Alex Pandian to TMDB ID 155491
# Mapped Ragada to TMDB ID 54069
# Mapped Run to TMDB ID 546121
# Mapped Chalo to TMDB ID 499789
# Mapped Munna to TMDB ID 460508
# Mapped Disco Raja to TMDB ID 535172
# Mapped Krishna and His Leela to TMDB ID 718745
# Mapped Yeto Vellipoyindhi Manasu to TMDB ID 149262
# Mapped Praana to TMDB ID 1182094
# No TMDB match found for Shankardada Zindabad, using fallback ID 100366
# Mapped Padi Padi Leche Manasu to TMDB ID 566139
# Mapped Punya Bhoomi Naa Desam to TMDB ID 927811
# Mapped Quick Gun Murugun: Misadventures of an Indian Cowboy to TMDB ID 21823
# No TMDB match found for Adavilo Anna, using fallback ID 100370
# Mapped Thamizh Padam to TMDB ID 107590
# Mapped Ek Niranjan to TMDB ID 38220
# Mapped Annavaram to TMDB ID 199806
# Mapped Bindaas to TMDB ID 80925
# Mapped Prema Katha Chitram to TMDB ID 200402
# Mapped Jagadeka Veerudu Athiloka Sundari to TMDB ID 77031
# Mapped Vismayam to TMDB ID 357262
# Mapped Missamma to TMDB ID 81089
# Mapped Gaddalakonda Ganesh to TMDB ID 611054
# Mapped Oka Laila Kosam to TMDB ID 298536
# Mapped Venky Mama to TMDB ID 613853
# Mapped Kick 2 to TMDB ID 607139
# Mapped Gayatri to TMDB ID 502703
# Mapped 180 to TMDB ID 65050
# Mapped Shourya to TMDB ID 420506
# Mapped Ashta Chamma to TMDB ID 80889
# Mapped Sigappu Rojakkal to TMDB ID 66413
# Mapped LIE to TMDB ID 18734
# Mapped Power to TMDB ID 1214558
# Mapped Dev to TMDB ID 811941
# Mapped Pataas to TMDB ID 331596
# Mapped Okkadu Migiladu to TMDB ID 486399
# Mapped Majnu to TMDB ID 500208
# Mapped Srinivasa Kalyanam to TMDB ID 540396
# Mapped Luck Unnodu to TMDB ID 440454
# Mapped Amma Nanna O Tamila Ammayi to TMDB ID 31350
# Mapped Jayasurya to TMDB ID 869152
# Mapped Bangaram to TMDB ID 199807
# Mapped Dora to TMDB ID 964878
# Mapped Don Seenu to TMDB ID 52944
# Mapped Vunnadhi Okate Zindagi to TMDB ID 483839
# Mapped Krishnam Vande Jagadgurum to TMDB ID 146819
# Mapped Killing Veerappan to TMDB ID 392567
# Mapped Gunturodu to TMDB ID 448908
# Mapped Mr. Majnu to TMDB ID 566143
# Mapped Not Today to TMDB ID 180345
# Mapped Oy! to TMDB ID 281135
# Mapped Nuvve.. Nuvve... to TMDB ID 484922
# Mapped Loukyam to TMDB ID 295587
# Mapped Swathi Muthyam to TMDB ID 900471
# Mapped Life Is Beautiful to TMDB ID 637
# Mapped Yuvaraju to TMDB ID 626994
# Mapped Chal Mohan Ranga to TMDB ID 508887
# No TMDB match found for Vamsee, using fallback ID 100414
# Mapped Endukante... Premanta to TMDB ID 153860
# Mapped Veyyil to TMDB ID 66224
# Mapped Mallesham to TMDB ID 610505
# Mapped Attack to TMDB ID 799155
# Mapped Mosagallaku Mosagadu to TMDB ID 301650
# Mapped Kandireega to TMDB ID 86712
# Mapped Raju Gari Gadhi 2 to TMDB ID 480812
# Mapped Superstar Kidnap to TMDB ID 307772
# Mapped Pournami to TMDB ID 226200
# Mapped Ninne Pelladatha to TMDB ID 137455
# Mapped Shailaja Reddy Alludu to TMDB ID 536429
# Mapped Jaya Janaki Nayaka to TMDB ID 466147
# Mapped Akkada Ammayi Ikkada Abbayi to TMDB ID 115050
# No TMDB match found for Pichhodu, using fallback ID 100429
# Mapped Bobby to TMDB ID 10741
# Mapped Okka Kshanam to TMDB ID 494987
# No TMDB match found for Achari America Yathra, using fallback ID 100432
# No TMDB match found for Sathyaa, using fallback ID 100433
# Mapped Bengal Tiger to TMDB ID 262918
# Mapped Ashok to TMDB ID 80864
# Mapped Coolie No. 1 to TMDB ID 614179
# Mapped Pathala Bhairavi to TMDB ID 89838
# Mapped Goutham Nanda to TMDB ID 465378
# Mapped Golmaal to TMDB ID 511640
# Mapped Mahanubhavudu to TMDB ID 478747
# Mapped 118 to TMDB ID 585564
# Mapped Heart Attack to TMDB ID 427897
# Mapped Dictator to TMDB ID 370720
# Mapped Idiot to TMDB ID 959848
# Mapped Neninthe to TMDB ID 137452
# Mapped Rarandoi Veduka Chudham to TMDB ID 458641
# Mapped Aswathama to TMDB ID 658113
# No TMDB match found for Yamajaathakudu, using fallback ID 100449
# Mapped Jaanu to TMDB ID 849173
# Mapped Neevevaro to TMDB ID 544681
# No TMDB match found for Power Unlimited 2, using fallback ID 100452
# Mapped Guru to TMDB ID 604108
# Mapped Kee to TMDB ID 489763
# Mapped Jagadam to TMDB ID 81062
# Mapped Daruvu to TMDB ID 152875
# Mapped Damarukam to TMDB ID 145335
# Mapped Super to TMDB ID 45132
# No TMDB match found for Krishna: The Power of Indrakeeladri, using fallback ID 100459
# Mapped Chakram to TMDB ID 132437
# Mapped Size Zero to TMDB ID 1311149
# Mapped Bhadra to TMDB ID 80924
# No TMDB match found for Erra Buss, using fallback ID 100463
# Mapped Lakshmi's NTR to TMDB ID 590753
# Mapped Dhoni to TMDB ID 1355466
# Mapped Appatlo Okadundevadu to TMDB ID 434295
# Mapped Akhil to TMDB ID 370986
# Mapped Daana Veera Soora Karna to TMDB ID 86137
# Mapped Aadhi Bhagavan to TMDB ID 69564
# Mapped Devudu Chesina Manushulu to TMDB ID 199544
# Mapped Falaknuma Das to TMDB ID 590162
# Mapped Raju Maharaju to TMDB ID 308298
# No TMDB match found for Adhipathi, using fallback ID 100473
# Mapped Peda Rayudu to TMDB ID 78840
# Mapped Nela Ticket to TMDB ID 526772
# Mapped Prati Roju Pandaage to TMDB ID 617646
# Mapped Veera to TMDB ID 684535
# Mapped Kotha Bangaru Lokam to TMDB ID 81999
# Mapped Santosham to TMDB ID 54304
# Mapped Venky to TMDB ID 881983
# Mapped Jai Simha to TMDB ID 495121
# Mapped Nuvve Kavali to TMDB ID 82200
# Mapped Samba to TMDB ID 269148
# Mapped Lava Kusa to TMDB ID 101736
# Mapped George Reddy to TMDB ID 649956
# Mapped Subramanyam for Sale to TMDB ID 377668
# Mapped Bhoot Returns to TMDB ID 140770
# Mapped Suswagatham to TMDB ID 199812
# Mapped Dohchay to TMDB ID 336082
# Mapped Andala Rakshasi to TMDB ID 154337
# Mapped Raja to TMDB ID 1362148
# No TMDB match found for Sambo Siva Sambho, using fallback ID 100492
# Mapped Okkadunnadu to TMDB ID 137471
# Mapped Manmadhudu 2 to TMDB ID 606714
# Mapped Paisa Vasool to TMDB ID 471331
# Mapped Lakshmi to TMDB ID 260267
# Mapped Chantabbai to TMDB ID 279295
# Mapped Anji to TMDB ID 1384565
# Mapped Dhada to TMDB ID 302472
# Mapped Uthama Puthiran to TMDB ID 261764
# Mapped Jai Chiranjeeva to TMDB ID 117415
# Mapped Magalir Mattum to TMDB ID 66355
# Mapped Anaganaga O Dheerudu to TMDB ID 72440
# Mapped Supreme Khiladi to TMDB ID 396378
# Mapped Aakali Rajyam to TMDB ID 66406
# No TMDB match found for Okka Magadu, using fallback ID 100506
# Mapped Phoonk 2 to TMDB ID 67973
# No TMDB match found for Tappu Chesi Pappu Koodu, using fallback ID 100508
# Mapped Bhairava Dweepam to TMDB ID 80944
# Mapped Needi Naadi Oke Katha to TMDB ID 513727
# Mapped Narasimha Naidu to TMDB ID 137440
# Mapped Chintakayala Ravi to TMDB ID 22052
# Mapped Yogi to TMDB ID 621753
# Mapped Yaman to TMDB ID 1179717
# Mapped Anando Brahma to TMDB ID 471469
# Mapped Vanaja to TMDB ID 54399
# Mapped Raja Vaaru Rani Gaaru to TMDB ID 617690
# Mapped Gangotri to TMDB ID 117092
# Mapped Golimar to TMDB ID 63469
# Mapped Narasimhudu to TMDB ID 279533
# Mapped Swayam Krushi to TMDB ID 848750
# Mapped Mental Madhilo to TMDB ID 492358
# Mapped Gaayam to TMDB ID 369485
# Mapped Rayalaseema Ramanna Chowdary to TMDB ID 82609
# Mapped Gokulamlo Seetha to TMDB ID 99158
# Mapped Rajanna to TMDB ID 200297
# Mapped Madha to TMDB ID 280951
# Mapped Hushaaru to TMDB ID 565278
# Mapped Settai to TMDB ID 180855
# Mapped Swarnakamalam to TMDB ID 82749
# Mapped Tadakha to TMDB ID 204395
# Mapped Nenu Naa Rakshasi to TMDB ID 82909
# Mapped Diya to TMDB ID 1085008
# Mapped Vikram to TMDB ID 578060
# Mapped Kadhal Desam to TMDB ID 12258
# Mapped Mudra to TMDB ID 511442
# No TMDB match found for Naa Autograph Sweet Memories, using fallback ID 100538
# Mapped Dum Dum Dum to TMDB ID 1134482
# Mapped Challenge to TMDB ID 1214667
# Mapped Kalisundam Raa to TMDB ID 81064
# Mapped Pandaga Chesko to TMDB ID 344823
# Mapped Daddy to TMDB ID 385124
# Mapped Seetha to TMDB ID 193197
# Mapped Kalki to TMDB ID 324622
# Mapped Parama Veera Chakra to TMDB ID 69927
# Mapped Samarasimha Reddy to TMDB ID 80827
# Mapped Andhrawala to TMDB ID 307746
# Mapped Hyper to TMDB ID 864637
# Mapped Kalloori to TMDB ID 78671
# Mapped Criminal to TMDB ID 302156
# Mapped Gharana Mogudu to TMDB ID 278184
# Mapped Namo Venkatesa to TMDB ID 94898
# Mapped Karnan to TMDB ID 680652
# Mapped Annayya to TMDB ID 669840
# Mapped Mesthri to TMDB ID 279121
# Mapped Little Soldiers to TMDB ID 411862
# Mapped Alludu Seenu to TMDB ID 315934
# Mapped Yuddham Sharanam to TMDB ID 474955
# Mapped Khaidi to TMDB ID 412326
# Mapped Shiva Shankar to TMDB ID 322298
# Mapped Bavagaru Bagunnara? to TMDB ID 80942
# Mapped Nannu Dochukunduvate to TMDB ID 549733
# Mapped Hello Brother to TMDB ID 39347
# Mapped Naa Alludu to TMDB ID 82168
# Mapped Shamantakamani to TMDB ID 466926
# Mapped Thulasi to TMDB ID 281023
# Mapped Keshava to TMDB ID 1391544
# Mapped Maja to TMDB ID 619779
# Mapped Aata to TMDB ID 63471
# Mapped Choodalani Vundi to TMDB ID 267115
# Mapped Ranarangam to TMDB ID 612005
# Mapped Mukunda to TMDB ID 880018
# No TMDB match found for Allari Police, using fallback ID 100576
# Mapped Kirrak Party to TMDB ID 508868
# No TMDB match found for Chenna Kesava Reddy, using fallback ID 100578
# Mapped Sarocharu to TMDB ID 199994
# Mapped Nadunisi Naaygal to TMDB ID 111589
# Mapped Nagavalli to TMDB ID 83154
# No TMDB match found for Ennaku 20 Unakku 18, using fallback ID 100582
# Mapped Bodyguard to TMDB ID 73582
# Mapped Raju Gari Gadhi 3 to TMDB ID 640559
# Mapped Josh to TMDB ID 646700
# Mapped Greeku Veerudu to TMDB ID 181930
# Mapped Lakshmi Narasimha to TMDB ID 81078
# Mapped Autonagar Surya to TMDB ID 253584
# Mapped Style to TMDB ID 20916
# Mapped Shivamani to TMDB ID 260016
# Mapped Surya vs. Surya to TMDB ID 332832
# Mapped Swathi Kiranam to TMDB ID 278035
# Mapped Alluda Majaaka! to TMDB ID 76116
# Mapped Kavacham to TMDB ID 565277
# Mapped Chinnadana Nee Kosam to TMDB ID 308034
# Mapped Hrudaya Kaleyam to TMDB ID 321162
# Mapped Mama Manchu Alludu Kanchu to TMDB ID 401901
# Mapped Prathinidhi to TMDB ID 1277697
# No TMDB match found for Meesrti, using fallback ID 100599
# Mapped Khatarnak to TMDB ID 730372
# Mapped Ritu to TMDB ID 496065
# Mapped Sri Ramadasu to TMDB ID 63434
# Mapped Jawaan to TMDB ID 185008
# Mapped Maalai Nerathu Mayakkam to TMDB ID 370711
# Mapped Janaki Ramudu to TMDB ID 81063
# Mapped Koduku Diddina Kapuram to TMDB ID 987973
# Mapped Subedar Joginder Singh to TMDB ID 510575
# Mapped Anasuya to TMDB ID 115068
# Mapped Postman to TMDB ID 508096
# Mapped Seven to TMDB ID 754137
# Mapped Jil to TMDB ID 71880
# Mapped Solo to TMDB ID 29621
# Mapped Andarivaadu to TMDB ID 307904
# Mapped Anthahpuram to TMDB ID 80859
# Mapped Samrat Ashok to TMDB ID 931326
# No TMDB match found for Aapathbandavudu, using fallback ID 100616
# Mapped Aaha Kalyanam to TMDB ID 251898
# Mapped Allari Pidugu to TMDB ID 280326
# Mapped Officer to TMDB ID 527862
# Mapped Paisa to TMDB ID 8429
# Mapped Yaan to TMDB ID 246030
# No TMDB match found for Alluri Seetharama Raju, using fallback ID 100622
# Mapped Adavi Donga to TMDB ID 279314
# Mapped Madhuram to TMDB ID 866435
# Mapped Vasu to TMDB ID 352113
# Mapped Saakshyam to TMDB ID 505908
# Mapped Shadow to TMDB ID 37813
# Mapped Babu Bangaram to TMDB ID 410572
# Mapped Shivam to TMDB ID 352618
# Mapped Rayudu to TMDB ID 663111
# Mapped Lion to TMDB ID 334543
# Mapped Pantham to TMDB ID 534343
# Mapped Govindha Govindha to TMDB ID 462350
# Mapped Nippu to TMDB ID 280359
# Mapped Pasivadi Pranam to TMDB ID 279288
# Mapped Chanakya to TMDB ID 607885
# Mapped Kondaveeti Raja to TMDB ID 279298
# Mapped Jessie to TMDB ID 738053
# Mapped Ninu Veedani Needanu Nene to TMDB ID 609118
# Mapped E to TMDB ID 1278099
# Mapped Ramayanam to TMDB ID 80940
# No TMDB match found for Meeku Matrame Chepta, using fallback ID 100643
# Mapped Jay Jay to TMDB ID 408508
# Mapped Naaga to TMDB ID 326801
# Mapped Venkatadri Express to TMDB ID 242301
# Mapped Golkonda High School to TMDB ID 67677
# Mapped Khaidi No. 786 to TMDB ID 279133
# Mapped Morning Raga to TMDB ID 230188
# Mapped Hitler to TMDB ID 102155
# Mapped Anjaneyulu to TMDB ID 23788
# No TMDB match found for Khaidi Garu, using fallback ID 100652
# Mapped Thimiru to TMDB ID 76968
# Mapped Loafer to TMDB ID 103558
# Mapped Collector Garu to TMDB ID 1044960
# No TMDB match found for Tej I Love U, using fallback ID 100656
# Mapped Winner to TMDB ID 1039659
# Mapped Anveshana to TMDB ID 669123
# Mapped Ism to TMDB ID 594604
# Mapped Abhinetri to TMDB ID 1151678
# Mapped Allari Ramudu to TMDB ID 307738
# Mapped Devadasu to TMDB ID 307448
# Mapped Kodama Simham to TMDB ID 278182
# Mapped April 1 Vidudala to TMDB ID 40906
# Mapped Lankeshwarudu to TMDB ID 279128
# Mapped Kondaveeti Donga to TMDB ID 103227
# Mapped O Pitta Katha to TMDB ID 681657
# Mapped Mutamestri to TMDB ID 279121
# Mapped Subbu to TMDB ID 463736
# Mapped Pilla Nuvvu Leni Jeevitham to TMDB ID 303732
# No TMDB match found for Sri Ramulayya, using fallback ID 100671
# Mapped Boss to TMDB ID 228355
# Mapped Anaganaga Oka Roju to TMDB ID 38887
# Mapped Raghavendra to TMDB ID 202080
# Mapped Kondaveeti Simhasanam to TMDB ID 1142476
# Mapped Cinema Chupista Maava to TMDB ID 369215
# No TMDB match found for Sri Jagadguru Adi Shankara, using fallback ID 100677
# Mapped Hawaa to TMDB ID 725741
# Mapped Toofan to TMDB ID 228979
# Mapped Ongole Githa to TMDB ID 200013
# Mapped Chukkallo Chandrudu to TMDB ID 117051
# Mapped Indrudu Chandrudu to TMDB ID 66364
# Mapped Sankranthi to TMDB ID 279459
# Mapped Aa Okkati Adakku to TMDB ID 1282465
# Mapped Eeshwar to TMDB ID 117085
# Mapped Ratchakan to TMDB ID 307797
# Mapped Maruthu to TMDB ID 371429
# Mapped Yamudiki Mogudu to TMDB ID 279134
# Mapped Police Police to TMDB ID 11636
# Mapped Evvarikee Cheppoddu to TMDB ID 637917
# Mapped Sudigaadu to TMDB ID 155738
# Mapped Rama Rama Krishna Krishna to TMDB ID 66491
# Mapped Geethanjali to TMDB ID 280287
# Mapped Padamati Sandhya Ragam to TMDB ID 402346
# Mapped Sri Manjunatha to TMDB ID 66519
# Mapped Vennela to TMDB ID 266499
# Mapped Jaguar to TMDB ID 162987
# Mapped Marshal to TMDB ID 693462
# Mapped Master to TMDB ID 680829
# Mapped Maska to TMDB ID 686919
# Mapped Assembly Rowdy to TMDB ID 303259
# Mapped Mehbooba to TMDB ID 347839
# Mapped Sneham Kosam to TMDB ID 500189
# Mapped Sindhu Bhairavi to TMDB ID 313612
# Mapped Adhinayakudu to TMDB ID 168119
# Mapped Lakshyam to TMDB ID 81079
# Mapped Adavi Ramudu to TMDB ID 228096
# No TMDB match found for Kunti Puthrudu, using fallback ID 100708
# Mapped Mathangi to TMDB ID 392569
# Mapped Brahma to TMDB ID 333937
# Mapped Alludugaru to TMDB ID 80885
# Mapped Oka Chinna Viramam to TMDB ID 677089
# Mapped Nenu Lenu to TMDB ID 82253
# No TMDB match found for Mrugaraaju, using fallback ID 100714
# Mapped Bharani to TMDB ID 76974
# Mapped Dil to TMDB ID 223973
# Mapped Ullasanga Utsahanga to TMDB ID 82725
# Mapped Kedi to TMDB ID 392011
# Mapped Shock to TMDB ID 29237
# Mapped Jyo Achyutananda to TMDB ID 417829
# Mapped Mithunam to TMDB ID 207920
# Mapped Palasa 1978 to TMDB ID 680986
# Mapped Maro Charithra to TMDB ID 137280
# Mapped Pelli Pustakam to TMDB ID 429767
# Mapped Boy to TMDB ID 39356
# Mapped Yamaleela to TMDB ID 82720
# Mapped Suryavamsam to TMDB ID 78612
# Mapped Kaakki Sattai to TMDB ID 66379
# Mapped Ammoru to TMDB ID 281872
# Mapped Ninnu Choodalani to TMDB ID 342799
# Mapped Premante Idera to TMDB ID 279472
# Mapped Ninaithale Inikkum to TMDB ID 111622
# Mapped Jayam to TMDB ID 226829
# Mapped Mugguru to TMDB ID 307773
# Mapped Ganesh to TMDB ID 23782
# Mapped Vangaveeti to TMDB ID 432342
# Mapped Chandamama Kathalu to TMDB ID 264306
# Mapped Chandamama to TMDB ID 264306
# Mapped Rowdy Fellow to TMDB ID 301668
# Mapped Shirdi Sai to TMDB ID 138078
# Mapped Sisindri to TMDB ID 307954
# Mapped Manasantha Nuvve to TMDB ID 77038
# Mapped Seetharamaiah Gari Manavaralu to TMDB ID 689299
# Mapped Bhale Manchi Roju to TMDB ID 413342
# Mapped Devi Putrudu to TMDB ID 279467
# Mapped Super Duper to TMDB ID 636621
# No TMDB match found for Subhash Chandra Bose, using fallback ID 100749
# Mapped Hyderabad Blues 2 to TMDB ID 407176
# Mapped Vijetha to TMDB ID 279310
# Mapped Veera Bhoga Vasantha Rayalu to TMDB ID 557252
# Mapped Tik Tik Tik to TMDB ID 388757
# Mapped Detective Naarada to TMDB ID 308010
# Mapped Kalyana Vaibhogame to TMDB ID 387842
# Mapped Heza to TMDB ID 1248012
# Mapped Narthanasala to TMDB ID 402068
# Mapped Nenunnanu to TMDB ID 265973
# Mapped Veedevadandi Babu to TMDB ID 404052
# Mapped Sirivennela to TMDB ID 82770
# Mapped Routine Love Story to TMDB ID 166460
# No TMDB match found for Intlo Illalu Vantaintlo Priyuralu, using fallback ID 100763
# Mapped Guna 369 to TMDB ID 319832
# Mapped Anandam to TMDB ID 80834
# Mapped Masala to TMDB ID 332983
# Mapped Entha Manchivaadavuraa to TMDB ID 633146
# Mapped Ruler to TMDB ID 34295
# Mapped Om Namo Venkatesaya to TMDB ID 443640
# Mapped Gundello Godari to TMDB ID 174877
# Mapped Rowdy Gari Pellam to TMDB ID 82611
# Mapped Paper Boy to TMDB ID 541267
# Mapped Mister to TMDB ID 1372693
# Mapped Raju Gari Gadhi to TMDB ID 640559
# Mapped Thodarum to TMDB ID 279890
# Mapped Allari Mogudu to TMDB ID 665049
# Mapped Nirnayam to TMDB ID 198359
# No TMDB match found for Dharma Bhai, using fallback ID 100778
# Mapped Software Sudheer to TMDB ID 660671
# Mapped Bhageeratha to TMDB ID 226197
# Mapped Azaad to TMDB ID 115265
# Mapped Minugurulu to TMDB ID 253560
# No TMDB match found for Raaja Paarvai, using fallback ID 100783
# No TMDB match found for Vijayendra Varama, using fallback ID 100784
# Mapped Mogudu to TMDB ID 80947
# Mapped Jayam Manadera to TMDB ID 117417
# Mapped Oxygen to TMDB ID 18561
# No TMDB match found for Athaku Yamudu Ammayiki Mogudu, using fallback ID 100788
# Mapped Sindhooram to TMDB ID 82777
# No TMDB match found for Bezawada, using fallback ID 100790
# Mapped Satyam to TMDB ID 333876
# Mapped Avunu Valliddaru Ishtapaddaru to TMDB ID 80923
# Mapped Baladoor to TMDB ID 115267
# Mapped 2 Hours Love to TMDB ID 631934
# Mapped Sakalakala Vallavan to TMDB ID 327915
# Mapped MLA to TMDB ID 1077437
# Mapped Appula Appa Rao to TMDB ID 180736
# Mapped Radha to TMDB ID 1150093
# Mapped Ladies Tailor to TMDB ID 461891
# Mapped Abhilasha to TMDB ID 278423
# Mapped Srimannarayana to TMDB ID 634077
# Mapped Katha Screenplay Darsakatvam: Appalaraju to TMDB ID 82901
# Mapped Chandralekha to TMDB ID 78643
# Mapped Maharadhi to TMDB ID 266496
# Mapped Speedunnodu to TMDB ID 449733
# Mapped Subhalekha to TMDB ID 267687
# Mapped Asura to TMDB ID 466403
# Mapped Palnati Brahmanayudu to TMDB ID 280328
# Mapped @ Nartanasala to TMDB ID 549541
# Mapped Nuvvu Nenu to TMDB ID 307924
# No TMDB match found for Rowdy Mogudu, using fallback ID 100811
# Mapped Ravoyi Chandamama to TMDB ID 214022
# Mapped Dream to TMDB ID 1163780
# Mapped Preminchukundam Raa to TMDB ID 82600
# Mapped Vasantham to TMDB ID 279463
# Mapped Chanti to TMDB ID 541795
# Mapped Bobbili Raja to TMDB ID 40907
# Mapped Kataka to TMDB ID 480268
# Mapped Dongala Mutha to TMDB ID 137249
# No TMDB match found for Chitemma Mogudu, using fallback ID 100821
# Mapped Subha Sankalpam to TMDB ID 737962
# No TMDB match found for Maa Inti Katha, using fallback ID 100823
# Mapped W/o Ram to TMDB ID 536771
# Mapped James Bond to TMDB ID 266315
# Mapped Padmavyuham to TMDB ID 1426207
# Mapped Avunu to TMDB ID 339925
# Mapped Veerabhadra to TMDB ID 267354
# Mapped Iddaru Mitrulu to TMDB ID 210055
# No TMDB match found for Singham123, using fallback ID 100830
# Mapped Anaamika to TMDB ID 263428
# Mapped Sasirekha Parinayam to TMDB ID 37815
# Mapped Bendu Apparao RMP to TMDB ID 117008
# Mapped Rajaratha to TMDB ID 513394
# Mapped Danger to TMDB ID 132445
# Mapped Andari Bandhuvaya to TMDB ID 80833
# Mapped Seenu to TMDB ID 279471
# Mapped Janda Pai Kapiraju to TMDB ID 263995
# Mapped Deyyam to TMDB ID 1135898
# Mapped Rowdy Alludu to TMDB ID 279122
# Mapped Krishna Aur Kans to TMDB ID 141139
# Mapped Seema Tapakai to TMDB ID 69925
# Mapped Mahathma to TMDB ID 23771
# Mapped Baanam to TMDB ID 23783
# Mapped Bhai to TMDB ID 361992
# Mapped Itlu Sravani Subramanyam to TMDB ID 307848
# Mapped Sathyam to TMDB ID 357147
# Mapped Bhale Ramudu to TMDB ID 1383992
# Mapped Pressure Cooker to TMDB ID 1245671
# Mapped Ranam to TMDB ID 1246021
# Mapped Aavida Maa Aavide to TMDB ID 115048
# Mapped Alavuddinum Athbutha Vilakkum to TMDB ID 66304
# Mapped Naa Mogudu Nanke Sontham to TMDB ID 931356
# Mapped Sri Anjaneyam to TMDB ID 66517
# Mapped Chiru Navvuto to TMDB ID 137248
# Mapped Operation Gold Fish to TMDB ID 624597
# Mapped Subrahmanyapuram to TMDB ID 565247
# Mapped Baava to TMDB ID 117005
# No TMDB match found for Veera Prathap, using fallback ID 100859
# Mapped Courier Boy Kalyan to TMDB ID 456983
# Mapped Jabardasth to TMDB ID 168246
# Mapped Pellam Oorelithe to TMDB ID 82298
# Mapped Hanuman Junction to TMDB ID 66520
# Mapped Money to TMDB ID 422874
# Mapped Ninnu Thalachi to TMDB ID 640550
# Mapped Jayammu Nischayammuu Raa to TMDB ID 430703
# Mapped A Film by Aravind to TMDB ID 80949
# Mapped Ye Mantram Vesave to TMDB ID 510333
# Mapped Bhakta Prahlada to TMDB ID 1073501
# Mapped Souryam to TMDB ID 73140
# Mapped Blade Babji to TMDB ID 80943
# Mapped Devi to TMDB ID 690617
# Mapped Gulabi to TMDB ID 1275137
# No TMDB match found for Rajendrudru Gajendrudru, using fallback ID 100874
# Mapped Lovely to TMDB ID 122783
# No TMDB match found for Adhirindhi Alludu, using fallback ID 100876
# Mapped Andhrudu to TMDB ID 80836
# Mapped Bluff Master to TMDB ID 571435
# Mapped Aatagadharaa Siva to TMDB ID 567884
# Mapped Rechipo to TMDB ID 23773
# Mapped Kadhal Sadugudu to TMDB ID 69667
# Mapped Ra Ra Krishnayya to TMDB ID 304791
# No TMDB match found for Nuvvu Vasthavani, using fallback ID 100884
# Mapped Prathigna to TMDB ID 987601
# Mapped Life Before Wedding to TMDB ID 85307
# Mapped Silly Fellows to TMDB ID 548382
# No TMDB match found for Donga Police, using fallback ID 100888
# Mapped Sundara Kanda to TMDB ID 279489
# Mapped Chitram Bhalare Vichitram to TMDB ID 81000
# Mapped Ninne Premistha to TMDB ID 307920
# Mapped Sahasa Veerudu Sagara Kanya to TMDB ID 279479
# Mapped Bhookailas to TMDB ID 155177
# Mapped Antham to TMDB ID 448322
# Mapped Ami Thumi to TMDB ID 462166
# Mapped Oka Manasu to TMDB ID 399146
# Mapped Aatadista to TMDB ID 258351
# Mapped Poola Rangadu to TMDB ID 91833
# Mapped Kitakitalu to TMDB ID 311637
# Mapped Money Money to TMDB ID 34280
# Mapped Prema Katha to TMDB ID 200402
# Mapped Enga Veetu Pillai to TMDB ID 263696
# No TMDB match found for Sitaramaraju, using fallback ID 100904
# No TMDB match found for Desa dimmari, using fallback ID 100905
# Mapped Sparsha to TMDB ID 256041
# Mapped Case No. 666/2013 to TMDB ID 169635
# Mapped I Love You to TMDB ID 4580
# Mapped Nayaki to TMDB ID 1069953
# Mapped Ee Rojullo to TMDB ID 199547
# Mapped Kamma Rajyam Lo Kadapa Reddlu to TMDB ID 656229
# Mapped Mugguru Monagallu to TMDB ID 279116
# Mapped 24 Kisses to TMDB ID 562974
# Mapped Next Enti? to TMDB ID 568212
# Mapped Naa Bangaaru Talli to TMDB ID 395061
# Mapped Anthaka Mundu Aa Tarvatha to TMDB ID 217225
# Mapped Edadugula Bandham to TMDB ID 803501
# Mapped Naa Nuvve to TMDB ID 530071
# Mapped All the Best to TMDB ID 171102
# No TMDB match found for Ranga (S.S.L.C), using fallback ID 100920
# No TMDB match found for Maanavudu Daanavudu, using fallback ID 100921
# Mapped Athanokkade to TMDB ID 275871
# Mapped Seema Sastry to TMDB ID 82312
# Mapped Amma Cheppindi to TMDB ID 530749
# Mapped Kalyanaraman to TMDB ID 351496
# Mapped Sankham to TMDB ID 23784
# Mapped Ride to TMDB ID 330115
# Mapped Ave Kallu to TMDB ID 302128
# Mapped Suryakantham to TMDB ID 586753
# Mapped Bhale Dongalu to TMDB ID 113775
# Mapped Kousalya Krishnamurthy to TMDB ID 605245
# Mapped Andhhagadu to TMDB ID 460456
# Mapped Okka Ammayi Thappa to TMDB ID 402099
# No TMDB match found for Bheemli Kabadi Jattu, using fallback ID 100934
# Mapped Naa Ishtam to TMDB ID 155731
# No TMDB match found for Saptapadhi, using fallback ID 100936
# Mapped Voter to TMDB ID 610023
# Mapped Chaarulatha to TMDB ID 146658
# Mapped Prema Kavali to TMDB ID 99354
# Mapped Ontari to TMDB ID 137472
# Mapped Killer to TMDB ID 85247
# Mapped Mr. Pellam to TMDB ID 77039
# Mapped Ammammagarillu to TMDB ID 526770
# Mapped Brand Babu to TMDB ID 540180
# Mapped Bama Vijayam to TMDB ID 109751
# Mapped Mitrudu to TMDB ID 137353
# Mapped Mr. Medhavi to TMDB ID 420497
# Mapped Dharma Chakram to TMDB ID 81053
# Mapped Chettu Kinda Pleader to TMDB ID 307811
# Mapped Hippi to TMDB ID 522828
# Mapped Veta to TMDB ID 307800
# Mapped Aatagallu to TMDB ID 544758
# Mapped Thikka to TMDB ID 411629
# Mapped Dorasani to TMDB ID 611284
# Mapped Allari Bullodu to TMDB ID 258354
# Mapped Peddarikam to TMDB ID 1243148
# Mapped Kalathur Kannamma to TMDB ID 66434
# Mapped Raju Gadu to TMDB ID 528765
# Mapped Guntur Talkies to TMDB ID 408014
# Mapped Kshemanga Velli Labhamga Randi to TMDB ID 267350
# Mapped Kotha Janta to TMDB ID 227057
# Mapped Iddari Lokam Okate to TMDB ID 657777
# Mapped Eduruleni Manishi to TMDB ID 308019
# No TMDB match found for Mathru Devo Bhava, using fallback ID 100966
# Mapped Kittu Unnadu Jagratha to TMDB ID 446008
# Mapped Ice Cream to TMDB ID 1424174
# Mapped Nuvva Nena to TMDB ID 137462
# Mapped Rama Chakkani Seetha to TMDB ID 639106
# No TMDB match found for Jappanil Kalyanaraman, using fallback ID 100971
# Mapped Idaya Kovil to TMDB ID 277861
# Mapped Jaihind 2 to TMDB ID 280884
# Mapped Nuvvila to TMDB ID 82201
# No TMDB match found for Srivaariki Premalekha, using fallback ID 100975
# No TMDB match found for Mard Ki Zabaan 2, using fallback ID 100976
# Mapped Hyderabad Nawabs to TMDB ID 616870
# Mapped Veede to TMDB ID 308234
# Mapped Nari Nari Naduma Murari to TMDB ID 280368
# Mapped Mayalodu to TMDB ID 1275801
# Mapped Raja Vikramarka to TMDB ID 842992
# Mapped ABCD: American-Born Confused Desi to TMDB ID 204261
# Mapped Alludu Diddina Kapuram to TMDB ID 866604
# Mapped Hare Ram to TMDB ID 81061
# Mapped Yamagola to TMDB ID 82721
# Mapped Meendum Kokila to TMDB ID 66399
# Mapped M Dharmaraju M.A. to TMDB ID 585968
# No TMDB match found for Prema Panjaram, using fallback ID 100988
# Mapped Tenali Ramakrishna BA.BL to TMDB ID 622478
# Mapped Gowtham SSC to TMDB ID 531021
# Mapped Kanchana to TMDB ID 1144820
# Mapped Mayuri to TMDB ID 1178416
# Mapped Swayamvaram to TMDB ID 169364
# No TMDB match found for Seetharamula Kalyanam Lankalo, using fallback ID 100994
# Mapped Pavitra Bandham to TMDB ID 279477
# Mapped Bala Gopaludu to TMDB ID 280370
# Mapped Yuvakudu to TMDB ID 82316
# Mapped Jayammu Nischayammu Raa! to TMDB ID 341310
# Mapped Manchi Donga to TMDB ID 126206
# Mapped Big Boss to TMDB ID 12481
# Mapped Idam Jagath to TMDB ID 584520
# Mapped Happy Wedding to TMDB ID 540263
# Mapped Nuvvu Leka Nenu Lenu to TMDB ID 82253
# No TMDB match found for Thoongathey Tambi Thoongathey, using fallback ID 101004
# No TMDB match found for Bommana Brothers Chanadana Sisters, using fallback ID 101006
# Mapped Rowdy Inspector to TMDB ID 82606
# Mapped Sontham to TMDB ID 82574
# Mapped Annai Oru Aalayam to TMDB ID 66307
# Mapped Wanted to TMDB ID 1185394
# Mapped Panchakshari to TMDB ID 308283
# Mapped Snehamante Idera to TMDB ID 303916
# Mapped Soggadi Pellam to TMDB ID 307957
# Mapped Bhale Donga to TMDB ID 779733
# Mapped 1st Rank Raju to TMDB ID 610266
# Mapped Dongodu to TMDB ID 117071
# Mapped Devullu to TMDB ID 307821
# Mapped Sardar Papa Rayudu to TMDB ID 663111
# Mapped Pourudu to TMDB ID 265978
# Mapped Amrutha Ramam to TMDB ID 698337
# Mapped Prematho Raa to TMDB ID 279466
# Mapped Bumper Offer to TMDB ID 117035
# Mapped Mangamma Gari Manavadu to TMDB ID 280375
# Mapped Yudda Bhoomi to TMDB ID 279132
# No TMDB match found for Rayalaseema Love Story, using fallback ID 101026
# Mapped Soggadu to TMDB ID 319809
# Mapped Budget Padmanabham to TMDB ID 993856
# Mapped Swargam Narakam to TMDB ID 1090083
# Mapped Manmatha Leelai to TMDB ID 864754
# Mapped Emo Gurram Egaravachu to TMDB ID 253172
# Mapped Ayyare to TMDB ID 104728
# Mapped Valayam to TMDB ID 687355
# Mapped Babai Abbai to TMDB ID 155153
# Mapped Two Town Rowdy to TMDB ID 279500
# Mapped State Rowdy to TMDB ID 279127
# Mapped Aradhana to TMDB ID 279292
# No TMDB match found for Idhi Mamulu Prema Katha Kaadu, using fallback ID 101038
# Mapped Rey to TMDB ID 307615
# Mapped Prema Yuddham to TMDB ID 307999
# Mapped Samudram to TMDB ID 303307
# Mapped Kabaddi Kabaddi to TMDB ID 396574
# Mapped Sruthilayalu to TMDB ID 602816
# Mapped Rikshavodu to TMDB ID 279114
# Mapped Muthyala Muggu to TMDB ID 82215
# Mapped Napoleon to TMDB ID 43320
# Mapped Bazaar Rowdy to TMDB ID 1358577
# Mapped Pelli Sandadi to TMDB ID 322265
# No TMDB match found for Idi Ma Prema Katha, using fallback ID 101049
# Mapped Babu Baga Busy to TMDB ID 459803
# Mapped Rogue to TMDB ID 13022
# Mapped Bhanumathi & Ramakrishna to TMDB ID 721109
# Mapped S. P. Parasuram to TMDB ID 279118
# Mapped Ala Ela to TMDB ID 335363
# Mapped Kevvu Keka to TMDB ID 225547
# Mapped Mantra to TMDB ID 933138
# No TMDB match found for Runam, using fallback ID 101057
# No TMDB match found for Choopulu Kalasina Subhavela, using fallback ID 101058
# Mapped Manoharam to TMDB ID 1021910
# Mapped Agni to TMDB ID 809126
# Mapped Appu Chesi Pappu Koodu to TMDB ID 528917
# Mapped Siddu from Srikakulam to TMDB ID 82570
# Mapped Nachavule to TMDB ID 82176
# Mapped Yagnam to TMDB ID 82310
# Mapped Mee Sreyobhilashi to TMDB ID 530759
# No TMDB match found for Kadapa Redamma, using fallback ID 101066
# Mapped Ghatotkachudu to TMDB ID 436834
# Mapped Jagadeka Veeruni Katha to TMDB ID 307475
# Mapped Kanyasulkam to TMDB ID 86134
# Mapped Snehamera Jeevitham to TMDB ID 660905
# Mapped Kobbari Matta to TMDB ID 622602
# No TMDB match found for Dhruvanakshatram, using fallback ID 101072
# Mapped Per Sollum Pillai to TMDB ID 66372
# Mapped Vivaha Bhojanambu to TMDB ID 402354
# Mapped Shanti Kranti to TMDB ID 577977
# Mapped Sukumarudu to TMDB ID 307624
# Mapped Fitting Master to TMDB ID 81975
# Mapped Operation Duryodhana to TMDB ID 360847
# Mapped Prema to TMDB ID 341895
# Mapped Mooga Manasulu to TMDB ID 307768
# Mapped Ontari Poratam to TMDB ID 279499
# Mapped Tandra Paparayudu to TMDB ID 1430398
# Mapped Nireekshana to TMDB ID 450178
# No TMDB match found for Premaabhishekam, using fallback ID 101084
# Mapped Savaari to TMDB ID 716035
# Mapped Surya IPS to TMDB ID 66409
# Mapped Maharasan to TMDB ID 66358
# Mapped Chakravarthy to TMDB ID 279287
# Mapped Lover to TMDB ID 1219158
# Mapped Jadoogadu to TMDB ID 400761
# Mapped Allari Alludu to TMDB ID 500614
# Mapped Pandava Vanavasamu to TMDB ID 86147
# Mapped Mechanic Alludu to TMDB ID 279119
# Mapped Kondaveeti Simham to TMDB ID 86136
# Mapped Malini 22 to TMDB ID 251635
# Mapped Bobbili Simham to TMDB ID 280351
# Mapped Show to TMDB ID 200796
# No TMDB match found for Varasudochhadu, using fallback ID 101098
# Mapped Family Circus to TMDB ID 1414165
# Mapped Edurinti Mogudu Pakkinti Pellam to TMDB ID 41046
# Mapped Donga to TMDB ID 279316
# Mapped Aakhari Poratam to TMDB ID 307981
# Mapped Rough to TMDB ID 833720
# Mapped Paathshala to TMDB ID 305349
# Mapped Kathi Kanta Rao to TMDB ID 77802
# Mapped Pelli Chesukundam to TMDB ID 279475
# Mapped Black Tiger to TMDB ID 2805
# Mapped Sri Krishna Pandaveeyam to TMDB ID 89832
# Mapped Nakshatram to TMDB ID 461426
# Mapped Subhalagnam to TMDB ID 82782
# Mapped Hai Hai Nayaka to TMDB ID 371632
# Mapped Om Shanti to TMDB ID 8079
# Mapped Pellaina Kothalo to TMDB ID 81238
# No TMDB match found for Anukunnadi Okkati Ayyindhi Okati, using fallback ID 101115
# Mapped Grahanam to TMDB ID 494811
# No TMDB match found for Chinnabaabu, using fallback ID 101117
# Mapped Karthavyam to TMDB ID 81066
# Mapped Raakshasudu to TMDB ID 606224
# Mapped Neeya to TMDB ID 533674
# Mapped D for Dopidi to TMDB ID 253540
# Mapped Mugguru Kodukulu to TMDB ID 466506
# Mapped Balachandrudu to TMDB ID 466505
# Mapped Vinodam to TMDB ID 406735
# Mapped Vijay to TMDB ID 503449
# Mapped Sri Shirdi Saibaba Mahathyam to TMDB ID 80832
# Mapped Anthuleni Katha to TMDB ID 78581
# Mapped Mithai to TMDB ID 553735
# Mapped Tiger to TMDB ID 1259918
# Mapped Luv U Alia to TMDB ID 403843
# Mapped Brother of Bommali to TMDB ID 307751
# No TMDB match found for Mr. Pellikodukku, using fallback ID 101132
# Mapped Broker to TMDB ID 636225
# Mapped Current to TMDB ID 132440
# Mapped Evadi Gola Vadide to TMDB ID 298945
# Mapped Bangaru Bullodu to TMDB ID 789229
# Mapped Karma to TMDB ID 553928
# Mapped Murali Krishnudu to TMDB ID 577529
# Mapped Varasudu to TMDB ID 410308
# Mapped Seetha Rama Kalyanam to TMDB ID 1262244
# Mapped Rendu Rella Aaru to TMDB ID 707764
# Mapped Sampoorna Ramayanam to TMDB ID 467510
# No TMDB match found for Chuttalabbayi, using fallback ID 101143
# Mapped Columbus to TMDB ID 414453
# Mapped Raagala 24 Gantallo to TMDB ID 666904
# Mapped Andala Ramudu to TMDB ID 80878
# Mapped Brahma Puthrudu to TMDB ID 279505
# Mapped Alibaba Aradajanu Dongalu to TMDB ID 127927
# Mapped Thipparaa Meesam to TMDB ID 646330
# Mapped Sitaara to TMDB ID 82774
# No TMDB match found for Chettaniki Kallu Levu, using fallback ID 101151
# No TMDB match found for Manasuku Nachindhi, using fallback ID 101152
# Mapped Om 3D to TMDB ID 410275
# Mapped Action to TMDB ID 137599
# Mapped Dongala Bandi to TMDB ID 307892
# Mapped Sultan to TMDB ID 452606
# Mapped Love Today to TMDB ID 307962
# Mapped Samanyudu to TMDB ID 828827
# Mapped Sathruvu to TMDB ID 279492
# Mapped Gandeevam to TMDB ID 280267
# Mapped Punnami Naagu to TMDB ID 279359
# Mapped Jyothi Lakshmi to TMDB ID 371683
# Mapped Avakai Biryani to TMDB ID 115075
# Mapped Lorry Driver to TMDB ID 280365
# Mapped Padaharella Vayasu to TMDB ID 87627
# No TMDB match found for Prananiki Pranam, using fallback ID 101166
# Mapped Akasa Veedhilo to TMDB ID 757875
# Mapped Totti Gang to TMDB ID 228341
# Mapped Allari to TMDB ID 115056
# Mapped Savitri to TMDB ID 674662
# Mapped Peddinti Alludu to TMDB ID 707781
# Mapped 143 to TMDB ID 463477
# Mapped Superman to TMDB ID 1061474
# Mapped Abhinandana to TMDB ID 78751
# Mapped Justice Chowdhary to TMDB ID 86141
# Mapped Gharana Bullodu to TMDB ID 261568
# Mapped Intlo Ramayya Veedilo Krishnayya to TMDB ID 279350
# No TMDB match found for Anna Thamudu, using fallback ID 101178
# Mapped Krishnamma Kalipindi Iddarini to TMDB ID 621354
# Mapped Nandhi to TMDB ID 337679
# Mapped Sons of Ram to TMDB ID 168121
# Mapped Kondapalli Raja to TMDB ID 279486
# Mapped Bava Nachadu to TMDB ID 40908
# Mapped Seema Simham to TMDB ID 280330
# Mapped Sandade Sandadi to TMDB ID 308249
# Mapped Donga Ramudu to TMDB ID 308015
# Mapped Vetagadu to TMDB ID 304374
# Mapped Sher to TMDB ID 1456692
# No TMDB match found for Kaamannana Makkalu, using fallback ID 101189
# Mapped Vinayakudu to TMDB ID 81997
# Mapped Dongaata to TMDB ID 473894
# Mapped 90 ML to TMDB ID 505929
# Mapped Kathanam to TMDB ID 621068
# Mapped Ramudu Bheemudu to TMDB ID 407984
# Mapped Patel S.I.R to TMDB ID 467242
# No TMDB match found for Nagarahaavu, using fallback ID 101196
# Mapped Selfie Raja to TMDB ID 430121
# Mapped Wish You Happy Breakup to TMDB ID 427946
# Mapped Lovers to TMDB ID 1375599
# No TMDB match found for Ramudochhadu, using fallback ID 101200
# Mapped Radha Gopalam to TMDB ID 307944
# Mapped Donga Mogudu to TMDB ID 279291
# No TMDB match found for Rangula Raatnam, using fallback ID 101203
# Mapped Adda to TMDB ID 410305
# Mapped Kalidasu to TMDB ID 395735
# Mapped Ela Cheppanu to TMDB ID 117086
# Mapped Vishwanatha Nayakudu to TMDB ID 1328969
# No TMDB match found for Sri Madvirat Veera Brahmendra Swamy Charitra, using fallback ID 101208
# Mapped Madatha Kaaja to TMDB ID 85952
# Mapped Dollar Dreams to TMDB ID 117066
# Mapped Betting Bangarraju to TMDB ID 77799
# Mapped Athili Sathibabu LKG to TMDB ID 200029
# Mapped Vinara sodara veera kumara to TMDB ID 592746
# Mapped Tenali Ramakrishna to TMDB ID 622478
# Mapped Idi Kathakaadu to TMDB ID 429534
# Mapped Agni Nakshatram to TMDB ID 306344
# Mapped Bandipotu to TMDB ID 465571
# Mapped Onamalu to TMDB ID 308233
# Mapped Vaana to TMDB ID 926867
# Mapped Jodi to TMDB ID 1386709
# Mapped Madhumasam to TMDB ID 137271
# Mapped Team 5 to TMDB ID 466180
# Mapped Sandhippoma to TMDB ID 77018
# Mapped Ice Cream 2 to TMDB ID 412844
# Mapped Okkadine to TMDB ID 307779
# Mapped Kiccha Huccha to TMDB ID 300289
# Mapped Visakha Express to TMDB ID 281937
# Mapped Aaviri to TMDB ID 659381
# Mapped Brindavanam to TMDB ID 413042
# Mapped Rudranetra to TMDB ID 279126
# Mapped Kaali to TMDB ID 996348
# Mapped Bobbili Puli to TMDB ID 85954
# Mapped Manavoori Pandavulu to TMDB ID 714721
# Mapped Next Nuvve to TMDB ID 484922
# Mapped Joru to TMDB ID 1094508
# Mapped Ko antey koti to TMDB ID 414231
# Mapped Kalyan Ram Kathi to TMDB ID 81986
# No TMDB match found for Priyamyna Neeku..., using fallback ID 101241
# ...
# No poster path found for ID 100811.0 (Rowdy Mogudu)
# No poster path found for ID 279310.0 (Vijetha)
# No poster path found for ID 267354.0 (Veerabhadra)
# No poster path found for ID 1245671.0 (Pressure Cooker)
# No poster path found for ID 931356.0 (Naa Mogudu Nanke Sontham)
# Error fetching poster for ID 100859.0 (Veera Prathap): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/100859.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 168246.0 (Jabardasth)
# No poster path found for ID 1275137.0 (Gulabi)
# Error fetching poster for ID 100874.0 (Rajendrudru Gajendrudru): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/100874.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# Error fetching poster for ID 100884.0 (Nuvvu Vasthavani): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/100884.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 987601.0 (Prathigna)
# No poster path found for ID 81000.0 (Chitram Bhalare Vichitram)
# No poster path found for ID 399146.0 (Oka Manasu)
# No poster path found for ID 311637.0 (Kitakitalu)
# Error fetching poster for ID 100905.0 (Desa dimmari): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/100905.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 199547.0 (Ee Rojullo)
# No poster path found for ID 395061.0 (Naa Bangaaru Talli)
# No poster path found for ID 217225.0 (Anthaka Mundu Aa Tarvatha)
# Error fetching poster for ID 100920.0 (Ranga (S.S.L.C)): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/100920.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# Error fetching poster for ID 100921.0 (Maanavudu Daanavudu): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/100921.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# Error fetching poster for ID 100934.0 (Bheemli Kabadi Jattu): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/100934.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# Error fetching poster for ID 100936.0 (Saptapadhi): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/100936.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 1243148.0 (Peddarikam)
# Error fetching poster for ID 100966.0 (Mathru Devo Bhava): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/100966.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# Error fetching poster for ID 100971.0 (Jappanil Kalyanaraman): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/100971.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# Error fetching poster for ID 100976.0 (Mard Ki Zabaan 2): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/100976.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 866604.0 (Alludu Diddina Kapuram)
# No poster path found for ID 1144820.0 (Kanchana)
# No poster path found for ID 1178416.0 (Mayuri)
# Error fetching poster for ID 100994.0 (Seetharamula Kalyanam Lankalo): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/100994.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 82316.0 (Yuvakudu)
# No poster path found for ID 341310.0 (Jayammu Nischayammu Raa!)
# No poster path found for ID 126206.0 (Manchi Donga)
# No poster path found for ID 307957.0 (Soggadi Pellam)
# No poster path found for ID 117035.0 (Bumper Offer)
# No poster path found for ID 279132.0 (Yudda Bhoomi)
# Error fetching poster for ID 101026.0 (Rayalaseema Love Story): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101026.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 1090083.0 (Swargam Narakam)
# Error fetching poster for ID 101038.0 (Idhi Mamulu Prema Katha Kaadu): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101038.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 279114.0 (Rikshavodu)
# Error fetching poster for ID 101049.0 (Idi Ma Prema Katha): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101049.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 335363.0 (Ala Ela)
# Error fetching poster for ID 101057.0 (Runam): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101057.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 528917.0 (Appu Chesi Pappu Koodu)
# Error fetching poster for ID 101066.0 (Kadapa Redamma): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101066.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 436834.0 (Ghatotkachudu)
# Error fetching poster for ID 101072.0 (Dhruvanakshatram): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101072.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 81975.0 (Fitting Master)
# No poster path found for ID 360847.0 (Operation Duryodhana)
# No poster path found for ID 101084.0 (Premaabhishekam)
# No poster path found for ID 86136.0 (Kondaveeti Simham)
# No poster path found for ID 1414165.0 (Family Circus)
# No poster path found for ID 305349.0 (Paathshala)
# No poster path found for ID 371632.0 (Hai Hai Nayaka)
# Error fetching poster for ID 101115.0 (Anukunnadi Okkati Ayyindhi Okati): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101115.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 101117.0 (Chinnabaabu)
# No poster path found for ID 253540.0 (D for Dopidi)
# No poster path found for ID 406735.0 (Vinodam)
# No poster path found for ID 503449.0 (Vijay)
# No poster path found for ID 132440.0 (Current)
# No poster path found for ID 577529.0 (Murali Krishnudu)
# Error fetching poster for ID 101143.0 (Chuttalabbayi): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101143.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 127927.0 (Alibaba Aradajanu Dongalu)
# No poster path found for ID 101151.0 (Chettaniki Kallu Levu)
# No poster path found for ID 101152.0 (Manasuku Nachindhi)
# No poster path found for ID 307892.0 (Dongala Bandi)
# No poster path found for ID 307962.0 (Love Today)
# No poster path found for ID 707781.0 (Peddinti Alludu)
# No poster path found for ID 261568.0 (Gharana Bullodu)
# Error fetching poster for ID 101178.0 (Anna Thamudu): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101178.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 337679.0 (Nandhi)
# No poster path found for ID 279486.0 (Kondapalli Raja)
# No poster path found for ID 308249.0 (Sandade Sandadi)
# No poster path found for ID 1456692.0 (Sher)
# No poster path found for ID 407984.0 (Ramudu Bheemudu)
# Error fetching poster for ID 101196.0 (Nagarahaavu): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101196.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# Error fetching poster for ID 101200.0 (Ramudochhadu): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101200.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# Error fetching poster for ID 101203.0 (Rangula Raatnam): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101203.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 395735.0 (Kalidasu)
# No poster path found for ID 1328969.0 (Vishwanatha Nayakudu)
# Error fetching poster for ID 101208.0 (Sri Madvirat Veera Brahmendra Swamy Charitra): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101208.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 85952.0 (Madatha Kaaja)
# No poster path found for ID 117066.0 (Dollar Dreams)
# No poster path found for ID 306344.0 (Agni Nakshatram)
# No poster path found for ID 308233.0 (Onamalu)
# No poster path found for ID 85954.0 (Bobbili Puli)
# No poster path found for ID 414231.0 (Ko antey koti)
# Error fetching poster for ID 101241.0 (Priyamyna Neeku...): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101241.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 371630.0 (Bava Bava Panneeru)
# Error fetching poster for ID 101265.0 (Nene Raju Nene Manthri): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101265.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 279488.0 (Abbaigaru)
# No poster path found for ID 278200.0 (Raksha)
# No poster path found for ID 995368.0 (Mr. Theertha)
# No poster path found for ID 117076.0 (Ee Abbai Chala Manchodu)
# Error fetching poster for ID 101296.0 (Praja pratinidhi): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101296.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 303233.0 (123)
# Error fetching poster for ID 101311.0 (Avunu Part 2): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101311.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# Error fetching poster for ID 101312.0 (Kashi from Village): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101312.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# Error fetching poster for ID 101319.0 (Sri Kanaka Mahalakshmi Recording Dance Troupe): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101319.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# Error fetching poster for ID 101328.0 (Sardar Dharmanna): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101328.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 280372.0 (Muddula Mavayya)
# No poster path found for ID 1386018.0 (Parugo Parugu)
# No poster path found for ID 808494.0 (Devatha)
# No poster path found for ID 395075.0 (Ankuram)
# Error fetching poster for ID 101347.0 (Manthrigari Viyyankudu): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101347.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# Error fetching poster for ID 101349.0 (Maa Alludu Verygood): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101349.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# Error fetching poster for ID 101350.0 (Nampalli Nagu): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101350.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 847371.0 (Golmaal Govindam)
# No poster path found for ID 101364.0 (SMS - Siva Manasulo Sruthi)
# No poster path found for ID 282524.0 (Nammanna)
# No poster path found for ID 77713.0 (Sneha Geetham)
# Error fetching poster for ID 101371.0 (Evadithe Nakenti): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101371.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 101372.0 (Mosagalaku Mosagaadu)
# Error fetching poster for ID 101374.0 (Chinnabbayi): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101374.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# Error fetching poster for ID 101375.0 (Ugranarasimham): 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/101375.0?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
# No poster path found for ID 1017675.0 (Chal Mohana Ranga)
# No poster path found for ID 77037.0 (Maavichiguru)
# No poster path found for ID 137364.0 (Money Money More Money)
# No poster path found for ID 28887.0 (Evaraina Eppudaina)
# No poster path found for ID 262994.0 (9 Nelalu)
#                          title    Year Certificate  \
# 0      Bahubali: The Beginning  2015.0          UA
# 1  Baahubali 2: The Conclusion  2017.0          UA
# 2              1 - Nenokkadine  2014.0          UA
# 3                      Dhoom:3  2013.0          UA
# 4                       Ra.One  2011.0           U
#
#                                   genres  \
# 0              Action, Drama
# 1              Action, Drama
# 2           Action, Thriller
# 3           Action, Thriller
# 4  Action, Adventure, Sci-Fi
#
#                                             overview  Runtime  Rating  \
# 0      In ancient India, an adventurous and darin...      159     8.1
# 1      When Shiva, the son of Bahubali, learns ab...      167     8.2
# 2      A rock star must overcome his psychologica...      170     8.1
# 3      When Sahir, a circus entertainer trained i...      172     5.4
# 4      When the titular antagonist of an action g...      156     4.6
#
#    No.of.Ratings        id original_language  \
# 0          99114  271726.0                te
# 1          71458  325561.0                te
# 2          42372  134374.0                te
# 3          42112   44977.0                te
# 4          37211   56703.0                te
#
#                                               poster
# 0  https://image.tmdb.org/t/p/w500//56DErD8o0rTxK...
# 1  https://image.tmdb.org/t/p/w500//txwqjwp5l9ApK...
# 2  https://image.tmdb.org/t/p/w500//txagTxnwbpSOv...
# 3  https://image.tmdb.org/t/p/w500//rUVTM5EQUQ2I0...
# 4                                               None
# Unmapped titles: ['Veer - Vivegam', 'Nuvvu Naaku Nachchav', 'Raja Kumarudu', 'Ramayya Vastavayya', 'Rudra Veena', 'Sokkali Mainor', 'MalliRaava', 'Ragile Gundelu', 'Shankardada Zindabad', 'Adavilo Anna', 'Vamsee', 'Pichhodu', 'Achari America Yathra', 'Sathyaa', 'Yamajaathakudu', 'Power Unlimited 2', 'Krishna: The Power of Indrakeeladri', 'Erra Buss', 'Adhipathi', 'Sambo Siva Sambho', 'Okka Magadu', 'Tappu Chesi Pappu Koodu', 'Naa Autograph Sweet Memories', 'Allari Police', 'Chenna Kesava Reddy', 'Ennaku 20 Unakku 18', 'Meesrti', 'Aapathbandavudu', 'Alluri Seetharama Raju', 'Meeku Matrame Chepta', 'Khaidi Garu', 'Tej I Love U', 'Sri Ramulayya', 'Sri Jagadguru Adi Shankara', 'Kunti Puthrudu', 'Mrugaraaju', 'Subhash Chandra Bose', 'Intlo Illalu Vantaintlo Priyuralu', 'Dharma Bhai', 'Raaja Paarvai', 'Vijayendra Varama', 'Athaku Yamudu Ammayiki Mogudu', 'Bezawada', 'Rowdy Mogudu', 'Chitemma Mogudu', 'Maa Inti Katha', 'Singham123', 'Veera Prathap', 'Rajendrudru Gajendrudru', 'Adhirindhi Alludu', 'Nuvvu Vasthavani', 'Donga Police', 'Sitaramaraju', 'Desa dimmari', 'Ranga (S.S.L.C)', 'Maanavudu Daanavudu', 'Bheemli Kabadi Jattu', 'Saptapadhi', 'Mathru Devo Bhava', 'Jappanil Kalyanaraman', 'Srivaariki Premalekha', 'Mard Ki Zabaan 2', 'Prema Panjaram', 'Seetharamula Kalyanam Lankalo', 'Thoongathey Tambi Thoongathey', 'Bommana Brothers Chanadana Sisters', 'Rayalaseema Love Story', 'Idhi Mamulu Prema Katha Kaadu', 'Idi Ma Prema Katha', 'Runam', 'Choopulu Kalasina Subhavela', 'Kadapa Redamma', 'Dhruvanakshatram', 'Premaabhishekam', 'Varasudochhadu', 'Anukunnadi Okkati Ayyindhi Okati', 'Chinnabaabu', 'Mr. Pellikodukku', 'Chuttalabbayi', 'Chettaniki Kallu Levu', 'Manasuku Nachindhi', 'Prananiki Pranam', 'Anna Thamudu', 'Kaamannana Makkalu', 'Nagarahaavu', 'Ramudochhadu', 'Rangula Raatnam', 'Sri Madvirat Veera Brahmendra Swamy Charitra', 'Priyamyna Neeku...', 'Nene Raju Nene Manthri', 'Ammo Okato Tariku', 'Stoovertpuram Police Station', 'Samsaaram Oka Chadarangam', 'Intinti Bhagavatham', 'Uyarntha Ullam', 'Praja pratinidhi', 'Jai Bolo Telangana', 'Avunu Part 2', 'Kashi from Village', 'Papikondalu', 'Sri Kanaka Mahalakshmi Recording Dance Troupe', 'Intlo Dayyam Nakemi Bhayam', 'Gruha Pravesam', 'Sardar Dharmanna', 'Manthrigari Viyyankudu', 'Maa Alludu Verygood', 'Nampalli Nagu', 'Kurukshetramu', 'SMS - Siva Manasulo Sruthi', 'Evadithe Nakenti', 'Mosagalaku Mosagaadu', 'Chinnabbayi', 'Ugranarasimham', 'Paramanandayya Shishyula Katha', 'Maro Monagadu']

# %%
print(self.movies_with_credits[['cast', 'crew']].head())
self.movies_with_credits['cast'] = self.movies_with_credits['cast'].astype(str).fillna('')
self.movies_with_credits['crew'] = self.movies_with_credits['crew'].astype(str).fillna('')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(self.movies_with_credits[['cast', 'crew']].head())
#       2 self.movies_with_credits['cast'] = self.movies_with_credits['cast'].astype(str).fillna('')
#       3 self.movies_with_credits['crew'] = self.movies_with_credits['crew'].astype(str).fillna('')
#
# NameError: name 'self' is not defined

# %%
import pandas as pd

# Load datasets
movies_df = pd.read_csv("../data/movies.csv")
credits_df = pd.read_csv("../data/credits.csv")
telugu_movies_df = pd.read_csv("../data/TeluguMovies_enhanced.csv")

# Check genres in movies_df
print("Movies genres issues:")
print(movies_df[movies_df['genres'].apply(lambda x: not pd.isna(x) and not x.startswith('['))]['genres'].head())

# Check cast and crew in credits_df
print("\nCredits cast issues:")
print(credits_df[credits_df['cast'].apply(lambda x: not pd.isna(x) and not x.startswith('['))]['cast'].head())
print("\nCredits crew issues:")
print(credits_df[credits_df['crew'].apply(lambda x: not pd.isna(x) and not x.startswith('['))]['crew'].head())

# Check genres in telugu_movies_df
print("\nTelugu movies genres issues:")
print(telugu_movies_df[telugu_movies_df['genres'].apply(lambda x: not pd.isna(x) and not x.startswith('['))]['genres'].head())
# Out:
# Movies genres issues:
# Series([], Name: genres, dtype: object)
#
# Credits cast issues:
# Series([], Name: cast, dtype: object)
#
# Credits crew issues:
# Series([], Name: crew, dtype: object)
#
# Telugu movies genres issues:
# 0                Action, Drama
# 1                Action, Drama
# 2             Action, Thriller
# 3             Action, Thriller
# 4    Action, Adventure, Sci-Fi
# Name: genres, dtype: object
